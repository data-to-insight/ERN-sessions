# %%
def print_variable(x):
    phrase = f'My name is {x}'
    print(phrase)

print_variable("Will")
# Out:
# My name is Will

# %%
def sum_xy(x, y):
    z = x + y
    print(y)

# sum_xy(y=10, x=5)

# write a function called minus_xy that takes y from x and prints the answer

j = 100

def minus_xy(x, y):
    z = x - y
    return z
     

answer = minus_xy(10, 7)
print(answer)
# Out:
# 3

# %%
def maths_xy(x, y):
    minus = x - y
    plus = x + y
    return minus, plus

x_minus_y, x_plus_y = maths_xy(100, 20)
print(x_minus_y)
print(x_plus_y)

# make a function called more_maths that timeses x and y, and divides x by y
# (* for times, and / for divide)
# Print out the answers as seprate variables
# Out:
# 80
# 120

# %%
def more_maths(x, y):
    prod = x * y
    division = x / y
    return prod, division

prod_xy, div_xy = more_maths(100, 20)

print(prod_xy)
print(int(div_xy))
# Out:
# 2000
# 5

# %%
def further_maths(x, y):
    def addition_ab(a, b):
        return a + b
    def subtraction_ab(m, n):
        return m - n
    return addition_ab(a=x, b=y), subtraction_ab(m=x, n=y)


print(further_maths(100, 5))
# Out:
# (105, 95)

# %%
def function_1(x, y):
    return f'function 1 says x and y are {x}, and {y}'

def function_2(x, y):
    return f'function 2 says that x and y are {x}, and {y}'

def nested_func(j, k):
    var_1 = function_1(j, k)
    var_2 = function_2(j, k)
    return var_1, var_2

print(nested_func('Hi', 'Hello'))

# Write two sub functions, each that take ONE argument, one takes a forename,
# one takes a last name, and print, repsectively 
# Hello my forename is FORNAME
# Hello my surname is SURNAME
# Then a nested function that take two arguemnts, and returns the answer from 
# both sub phrases
# Print the answer

def my_forename(forename):
    return f'Hello, my name is {forename}'

def my_surname(surname):
    return f'My surname is {surname}'

def name_function(fname, sname):
    return my_forename(fname), my_surname(sname)

names = name_function(fname='Will', sname='Levack-Payne')
print(names)
# Out:
# ('function 1 says x and y are Hi, and Hello', 'function 2 says that x and y are Hi, and Hello')
# ('Hello, my name is Will', 'My surname is Levack-Payne')

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv'

df = pd.read_csv(url)

df
# Out:
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# 3                               20044
# 4                               20044
# ..                                ...
# 518                            282548
# 519                            283871
# 520                            285053
# 521                            288281
# 522                            289824
#
#      Percentage change (monthly) All property types  \
# 0                                              3.94
# 1                                              3.94
# 2                                              3.94
# 3                                              4.00
# 4                                              4.00
# ..                                              ...
# 518                                           -1.00
# 519                                            0.50
# 520                                            0.40
# 521                                            1.10
# 522                                            0.50
#
#      Percentage change (yearly) All property types
# 0                                            28.59
# 1                                            28.59
# 2                                            28.59
# 3                                            24.15
# 4                                            24.15
# ..                                             ...
# 518                                           3.20
# 519                                           2.50
# 520                                           1.60
# 521                                           1.90
# 522                                           0.60
#
# [523 rows x 6 columns]

# %%
mean_pct_change = df['Percentage change (monthly) All property types'].mean()

# print(mean_pct_change)

def change_checker(pct_change):
    if pct_change > mean_pct_change:
        return 'Greater than average'
    if pct_change < mean_pct_change:
        return 'Less than average'
    else:
        return 'Exactly Average'
    
df['Change ratio'] = df['Percentage change (monthly) All property types'].apply(change_checker)

df

# DO the same but for Average price All property types
# Out:
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# 3                               20044
# 4                               20044
# ..                                ...
# 518                            282548
# 519                            283871
# 520                            285053
# 521                            288281
# 522                            289824
#
#      Percentage change (monthly) All property types  \
# 0                                              3.94
# 1                                              3.94
# 2                                              3.94
# 3                                              4.00
# 4                                              4.00
# ..                                              ...
# 518                                           -1.00
# 519                                            0.50
# 520                                            0.40
# 521                                            1.10
# 522                                            0.50
#
#      Percentage change (yearly) All property types          Change ratio
# 0                                            28.59  Greater than average
# 1                                            28.59  Greater than average
# 2                                            28.59  Greater than average
# 3                                            24.15  Greater than average
# 4                                            24.15  Greater than average
# ..                                             ...                   ...
# 518                                           3.20     Less than average
# 519                                           2.50     Less than average
# 520                                           1.60     Less than average
# 521                                           1.90     Less than average
# 522                                           0.60     Less than average
#
# [523 rows x 7 columns]

# %%
mean_price = df['Average price All property types'].mean()

# print(mean_pct_change)

def price_checker(price):
    if price > mean_price:
        return 'Greater than average'
    if price < mean_price:
        return 'Less than average'
    else:
        return 'Exactly Average'
    
df['Price check'] = df['Average price All property types'].apply(price_checker)

df
# Out:
#                Name   Period  House price index All property types  \
# 0    United Kingdom  1980-01                                 10.11
# 1    United Kingdom  1980-02                                 10.11
# 2    United Kingdom  1980-03                                 10.11
# 3    United Kingdom  1980-04                                 10.51
# 4    United Kingdom  1980-05                                 10.51
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 0                               19273
# 1                               19273
# 2                               19273
# 3                               20044
# 4                               20044
# ..                                ...
# 518                            282548
# 519                            283871
# 520                            285053
# 521                            288281
# 522                            289824
#
#      Percentage change (monthly) All property types  \
# 0                                              3.94
# 1                                              3.94
# 2                                              3.94
# 3                                              4.00
# 4                                              4.00
# ..                                              ...
# 518                                           -1.00
# 519                                            0.50
# 520                                            0.40
# 521                                            1.10
# 522                                            0.50
#
#      Percentage change (yearly) All property types          Change ratio  \
# 0                                            28.59  Greater than average
# 1                                            28.59  Greater than average
# 2                                            28.59  Greater than average
# 3                                            24.15  Greater than average
# 4                                            24.15  Greater than average
# ..                                             ...                   ...
# 518                                           3.20     Less than average
# 519                                           2.50     Less than average
# 520                                           1.60     Less than average
# 521                                           1.90     Less than average
# 522                                           0.60     Less than average
#
#               Price check
# 0       Less than average
# 1       Less than average
# 2       Less than average
# 3       Less than average
# 4       Less than average
# ..                    ...
# 518  Greater than average
# 519  Greater than average
# 520  Greater than average
# 521  Greater than average
# 522  Greater than average
#
# [523 rows x 8 columns]

# %%
df[df['Price check'] == 'Greater than average']
# Out:
#                Name   Period  House price index All property types  \
# 274  United Kingdom  2002-11                                 63.83
# 275  United Kingdom  2002-12                                 65.95
# 276  United Kingdom  2003-01                                 65.47
# 277  United Kingdom  2003-02                                 64.78
# 278  United Kingdom  2003-03                                 66.16
# ..              ...      ...                                   ...
# 518  United Kingdom  2023-03                                148.20
# 519  United Kingdom  2023-04                                148.90
# 520  United Kingdom  2023-05                                149.50
# 521  United Kingdom  2023-06                                151.20
# 522  United Kingdom  2023-07                                152.00
#
#      Average price All property types  \
# 274                            121700
# 275                            125747
# 276                            124836
# 277                            123521
# 278                            126152
# ..                                ...
# 518                            282548
# 519                            283871
# 520                            285053
# 521                            288281
# 522                            289824
#
#      Percentage change (monthly) All property types  \
# 274                                            1.01
# 275                                            3.33
# 276                                           -0.72
# 277                                           -1.05
# 278                                            2.13
# ..                                              ...
# 518                                           -1.00
# 519                                            0.50
# 520                                            0.40
# 521                                            1.10
# 522                                            0.50
#
#      Percentage change (yearly) All property types          Change ratio  \
# 274                                          24.23     Less than average
# 275                                          28.36  Greater than average
# 276                                          27.88     Less than average
# 277                                          22.10     Less than average
# 278                                          20.48  Greater than average
# ..                                             ...                   ...
# 518                                           3.20     Less than average
# 519                                           2.50     Less than average
# 520                                           1.60     Less than average
# 521                                           1.90     Less than average
# 522                                           0.60     Less than average
#
#               Price check
# 274  Greater than average
# 275  Greater than average
# 276  Greater than average
# 277  Greater than average
# 278  Greater than average
# ..                    ...
# 518  Greater than average
# 519  Greater than average
# 520  Greater than average
# 521  Greater than average
# 522  Greater than average
#
# [249 rows x 8 columns]
