# %%
var_1 = 10 # integer
var_2 = 10.10 # float - number with decimals
var_3 = "10" # string

type(var_3)

# indexes start at 0
# [start : stop : step]
# start is incusive, stop is exclusive 

alph = 'abcdefghijk'

alph[::2]
# Out:
# 'acegik'

# %%
# Lists -> allow us to store lists of variables
# Column names often lists

# Dictionary -> store variables in one object names (keys) : value
# filename <- keys, xlsx <- values

list_1 = [] # <- empty

type(list_1)
# Out:
# list

# %%
# lists keep their order (unless you change them)
cols_1 = ["red", "blue", ["green", "turquoise", "beige"]]
cols_2 = ["purple", "orange", cols_1]

cols_2[2][2][0]

# Write a list which contains: 
# a float, an integer, a string, and another list which itself contains strings
# use the square bracket notation to slice out and print the last string from the
# list inside the list (try and do it using a minus rather than a normal number)
# variables as standard are: lower case words, with _ between

excercise_list = [10.0, 2, "string", ["str1", 'str2']]

last_string = excercise_list[-1][-1]

last_string
# Out:
# 'str2'

# %%
# functions -> print() 
# methods -> var.name_of_fn()
# we don't need to know the difference
# is the thing we are using a fn. or a mthd. 

colours_1 = ["red", "blue", "green", "turquoise", "beige", "blue", 10]
colours_2 = ["teal", "maroon"]
colour_1 = "taupe"

# append
colours_1.append("brown") # it works in place
# it appends the whole thing to one element

# extend
colours_1.extend(colours_2)
# extends a list by indexable elements of something else (e.g. list or string)

# remove
colours_1.remove("blue") # remove works by taking ONLY one element with a given value
colours_1.remove(10)

colours_1
# Out:
# ['red', 'green', 'turquoise', 'beige', 'blue', 'brown', 'teal', 'maroon']

# %%
# In this cell, make a list of a few foods and print it.
foods = ['burger', 'pizza', 'pasta']
print(foods)

# Then append the list with another food and print it.
foods.append("pasty")
print(foods)
# Next, make another list of foods, and use the extend method to 
# add those extra foods as individual elements of the list, and print it.
more_foods = ["chocolate", "crackers"]
foods.extend(more_foods)
print(foods)

# Finally, remove and element from the list and print the final list.
# Remember to always use a suitable name for your lists!
foods.remove("crackers")
print(foods)
# Out:
# ['burger', 'pizza', 'pasta']
# ['burger', 'pizza', 'pasta', ['pasty']]
# ['burger', 'pizza', 'pasta', ['pasty'], 'chocolate', 'crackers']
# ['burger', 'pizza', 'pasta', ['pasty'], 'chocolate']

# %%
nums = [1, 5, 3, 9, 8, 74, 5, 3, 52]

# sort - can take the reverse argument
# True/False
# nums.sort(reverse=True)

nums = sorted(nums) # not changing a variable

print(nums)
print(nums_sorted)
# Out:
# [1, 5, 3, 9, 8, 74, 5, 3, 52]
# [1, 3, 3, 5, 5, 8, 9, 52, 74]

# %%
# keys : values
# immutable <- can't be changed: numbers, strings 
# 10 is always the number 10, "10" is always "10"

# list_nums = [10] -> list_nums.remove[10] -> []

fav_colours = {"Will":"black", 
               "Clare":"yellow",
               "Marcel":{"monday":["blue", "yellow"], "RoW":"Grey"}}

# standard way to access dictionaries
print(fav_colours["Marcel"]['monday'][0])

print(list(fav_colours.keys()))

print(list(fav_colours.values()))

print(list(fav_colours.items())) # tuple
# Out:
# blue
# ['Will', 'Clare', 'Marcel']
# ['black', 'yellow', {'monday': ['blue', 'yellow'], 'RoW': 'Grey'}]
# [('Will', 'black'), ('Clare', 'yellow'), ('Marcel', {'monday': ['blue', 'yellow'], 'RoW': 'Grey'})]

# %%
# make a dictionary of restaurants with keys being the name and values being the foods,
foods = {"Pub":"Sunday roast",
        "The chippy": ["Fish", "Chips"],
        "The Fine Dining Restaurant":{"Week days":['Fish', 'Chicken', 'Vegan Special'],
                                     "Weekends":'Tasting Menu'}
        }
# make sure at least one value is a list of foods, and another is a dicitonary of days and foods
# use the keys, vlaues, and items methods to views those

print(foods.keys())
print(foods.values())
print(foods.items())
print(foods["The Fine Dining Restaurant"].keys())
# Out:
# dict_keys(['Pub', 'The chippy', 'The Fine Dining Restaurant'])
# dict_values(['Sunday roast', ['Fish', 'Chips'], {'Week days': ['Fish', 'Chicken', 'Vegan Special'], 'Weekends': 'Tasting Menu'}])
# dict_items([('Pub', 'Sunday roast'), ('The chippy', ['Fish', 'Chips']), ('The Fine Dining Restaurant', {'Week days': ['Fish', 'Chicken', 'Vegan Special'], 'Weekends': 'Tasting Menu'})])
# dict_keys(['Week days', 'Weekends'])

# %%
fav_colours = {"Will":["black", "yellow"], 
               "Clare":"yellow",
               "Marcel":{"monday":["blue", "yellow"], "RoW":"Grey"}}

will_colours = fav_colours['Will']

fav_colours['Annie'] = "purple" # adding stuff

fav_colours["Will"] = "black" # overwriting stuff

print("Will" in fav_colours)

# Using the key, print the values of one of the restaurants in your dicitonary.
# Add a new key:value pair to your dictionary, as above.
# Check whether 'Coffee Shop' is a key in your dictionary, printing the answer.
# Out:
# True

# %%
foods = {"Pub":"Sunday roast",
        "The chippy": ["Fish", "Chips"],
        "The Fine Dining Restaurant":{"Week days":['Fish', 'Chicken', 'Vegan Special'],
                                     "Weekends":'Tasting Menu'}
        }

# Using the key, print the values of one of the restaurants in your dicitonary.
print(foods["Pub"])
# Add a new key:value pair to your dictionary, as above.
foods['Bakery'] = "Breads"

print(foods)
# Check whether 'Coffee Shop' is a key in your dictionary, printing the answer.

print("coffe shop" in foods)
# Out:
# Sunday roast
# {'Pub': 'Sunday roast', 'The chippy': ['Fish', 'Chips'], 'The Fine Dining Restaurant': {'Week days': ['Fish', 'Chicken', 'Vegan Special'], 'Weekends': 'Tasting Menu'}, 'Bakery': 'Breads'}
# False
